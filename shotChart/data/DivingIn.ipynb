# %%
import pandas as pd

# %%
# !ls
# Out:
# DivingIn.ipynb       shots-2006.csv       shots-2013.csv
# shots-2000-final.csv shots-2007-final.csv shots-2014-final.csv
# shots-2000.csv       shots-2007.csv       shots-2014.csv
# shots-2001-final.csv shots-2008-final.csv shots-2015-final.csv
# shots-2001.csv       shots-2008.csv       shots-2015.csv
# shots-2002-final.csv shots-2009-final.csv shots-2016-final.csv
# shots-2002.csv       shots-2009.csv       shots-2016.csv
# shots-2003-final.csv shots-2010-final.csv shots-2017-final.csv
# shots-2003.csv       shots-2010.csv       shots-2017.csv
# shots-2004-final.csv shots-2011-final.csv shots-2018-final.csv
# shots-2004.csv       shots-2011.csv       shots-2018.csv
# shots-2005-final.csv shots-2012-final.csv shots-2019.csv
# shots-2005.csv       shots-2012.csv
# shots-2006-final.csv shots-2013-final.csv

# %%
file_name = "shots-2019"

# %%
shots = pd.read_csv(file_name+".csv")

# %%
shots.head()
# Out:
#         game_id  year  month  day   winner        loser      x      y  \
# 0  201910220TOR  2019     10   22  Toronto  New Orleans  147px  242px
# 1  201910220TOR  2019     10   22  Toronto  New Orleans   27px  240px
# 2  201910220TOR  2019     10   22  Toronto  New Orleans   32px  320px
# 3  201910220TOR  2019     10   22  Toronto  New Orleans  152px  258px
# 4  201910220TOR  2019     10   22  Toronto  New Orleans  133px  366px
#
#                                                 play
# 0  1st quarter, 11:48.0 remaining<br>Lonzo Ball m...
# 1  1st quarter, 11:47.0 remaining<br>Derrick Favo...
# 2  1st quarter, 11:16.0 remaining<br>Jrue Holiday...
# 3  1st quarter, 11:00.0 remaining<br>Derrick Favo...
# 4  1st quarter, 10:37.0 remaining<br>Brandon Ingr...

# %%
game_ids = shots.drop_duplicates(subset='game_id')['game_id'].tolist()

# %%
len(game_ids)
# Out:
# 139

# %%
import datetime

# %%
list_of_columns = shots.columns.values.tolist() + ["time_remaining","quarter"]

# %%
print(list_of_columns)
# Out:
# ['game_id', 'year', 'month', 'day', 'winner', 'loser', 'x', 'y', 'play', 'time_remaining', 'quarter']

# %%
shots.loc[shots['game_id']=='200010310VAN'].head()
# Out:
# Empty DataFrame
# Columns: [game_id, year, month, day, winner, loser, x, y, play]
# Index: []

# %%
"1st quarter, 11:22.0 remaining<br>Patrick Ewin".split(' ')[2]
# Out:
# '11:22.0'

# %%
print(datetime.datetime.strptime("1st quarter, 11:22.0 remaining<br>Patrick Ewin".split(' ')[2], '%H:%M.%S'))
# Out:
# 1900-01-01 11:22:00

# %%
final_df = pd.DataFrame(columns=list_of_columns)

# %%
final_df
# Out:
# Empty DataFrame
# Columns: [game_id, year, month, day, winner, loser, x, y, play, time_remaining, quarter]
# Index: []

# %%
for game in game_ids:
    temp_df = shots.loc[shots['game_id']==game]
    temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S')) 
    temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0]) 

    temp_df = temp_df.sort_values(by=['quarter','time_remaining'],ascending=[True,False])
#     print(temp_df.head())
    final_df = final_df.append(temp_df)
# Out:
# /usr/local/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
final_df[final_df['game_id']== '200010310VAN']
# Out:
# Empty DataFrame
# Columns: [game_id, year, month, day, winner, loser, x, y, play, time_remaining, quarter]
# Index: []

# %%
final_df['time_remaining'] = final_df['play'].apply(lambda x: str(x).split(' ')[2])

# %%
final_df['shots_by'] = final_df['play'].apply(lambda x: str(x).split('<br>')[1].split(' ')[0]+" "+str(x).split('<br>')[1].split(' ')[1])

# %%
final_df.head()
# Out:
#           game_id  year month day   winner        loser      x      y  \
# 0    201910220TOR  2019    10  22  Toronto  New Orleans  147px  242px
# 1    201910220TOR  2019    10  22  Toronto  New Orleans   27px  240px
# 205  201910220TOR  2019    10  22  Toronto  New Orleans   60px  256px
# 2    201910220TOR  2019    10  22  Toronto  New Orleans   32px  320px
# 206  201910220TOR  2019    10  22  Toronto  New Orleans  208px  418px
#
#                                                   play time_remaining quarter  \
# 0    1st quarter, 11:48.0 remaining<br>Lonzo Ball m...        11:48.0       1
# 1    1st quarter, 11:47.0 remaining<br>Derrick Favo...        11:47.0       1
# 205  1st quarter, 11:29.0 remaining<br>OG Anunoby m...        11:29.0       1
# 2    1st quarter, 11:16.0 remaining<br>Jrue Holiday...        11:16.0       1
# 206  1st quarter, 11:11.0 remaining<br>Kyle Lowry m...        11:11.0       1
#
#            shots_by
# 0        Lonzo Ball
# 1    Derrick Favors
# 205      OG Anunoby
# 2      Jrue Holiday
# 206      Kyle Lowry

# %%
final_df['outcome'] = final_df['play'].apply(lambda x: str(x).split('<br>')[1].split(' ')[2])

# %%
final_df['attempt'] = final_df['play'].apply(lambda x: str(x).split('<br>')[1].split(' ')[3])

# %%
final_df.head()
# Out:
#           game_id  year month day   winner        loser      x      y  \
# 0    201910220TOR  2019    10  22  Toronto  New Orleans  147px  242px
# 1    201910220TOR  2019    10  22  Toronto  New Orleans   27px  240px
# 205  201910220TOR  2019    10  22  Toronto  New Orleans   60px  256px
# 2    201910220TOR  2019    10  22  Toronto  New Orleans   32px  320px
# 206  201910220TOR  2019    10  22  Toronto  New Orleans  208px  418px
#
#                                                   play time_remaining quarter  \
# 0    1st quarter, 11:48.0 remaining<br>Lonzo Ball m...        11:48.0       1
# 1    1st quarter, 11:47.0 remaining<br>Derrick Favo...        11:47.0       1
# 205  1st quarter, 11:29.0 remaining<br>OG Anunoby m...        11:29.0       1
# 2    1st quarter, 11:16.0 remaining<br>Jrue Holiday...        11:16.0       1
# 206  1st quarter, 11:11.0 remaining<br>Kyle Lowry m...        11:11.0       1
#
#            shots_by outcome    attempt
# 0        Lonzo Ball  missed  2-pointer
# 1    Derrick Favors    made  2-pointer
# 205      OG Anunoby  missed  2-pointer
# 2      Jrue Holiday  missed  2-pointer
# 206      Kyle Lowry  missed  3-pointer

# %%
final_df['distance'] = final_df['play'].apply(lambda x: str(x).split('<br>')[1].split(' ')[5]+str(x).split('<br>')[1].split(' ')[6])

# %%
final_df.head()
# Out:
#           game_id  year month day   winner        loser      x      y  \
# 0    201910220TOR  2019    10  22  Toronto  New Orleans  147px  242px
# 1    201910220TOR  2019    10  22  Toronto  New Orleans   27px  240px
# 205  201910220TOR  2019    10  22  Toronto  New Orleans   60px  256px
# 2    201910220TOR  2019    10  22  Toronto  New Orleans   32px  320px
# 206  201910220TOR  2019    10  22  Toronto  New Orleans  208px  418px
#
#                                                   play time_remaining quarter  \
# 0    1st quarter, 11:48.0 remaining<br>Lonzo Ball m...        11:48.0       1
# 1    1st quarter, 11:47.0 remaining<br>Derrick Favo...        11:47.0       1
# 205  1st quarter, 11:29.0 remaining<br>OG Anunoby m...        11:29.0       1
# 2    1st quarter, 11:16.0 remaining<br>Jrue Holiday...        11:16.0       1
# 206  1st quarter, 11:11.0 remaining<br>Kyle Lowry m...        11:11.0       1
#
#            shots_by outcome    attempt distance
# 0        Lonzo Ball  missed  2-pointer     11ft
# 1    Derrick Favors    made  2-pointer      1ft
# 205      OG Anunoby  missed  2-pointer      3ft
# 2      Jrue Holiday  missed  2-pointer      8ft
# 206      Kyle Lowry  missed  3-pointer     25ft

# %%
def get_team(play):
    team = play.split('<br>')[2].split(' ')
    if team[0] == "LA" or team[0] == "New" or team[0] == 'San' or team[0] == 'Golden':
        return team[0]+" "+team[1]
    else:
        return team[0]

# %%
final_df['team'] = final_df['play'].apply(lambda x: get_team(x))

# %%
final_df.head()
# Out:
#           game_id  year month day   winner        loser      x      y  \
# 0    201910220TOR  2019    10  22  Toronto  New Orleans  147px  242px
# 1    201910220TOR  2019    10  22  Toronto  New Orleans   27px  240px
# 205  201910220TOR  2019    10  22  Toronto  New Orleans   60px  256px
# 2    201910220TOR  2019    10  22  Toronto  New Orleans   32px  320px
# 206  201910220TOR  2019    10  22  Toronto  New Orleans  208px  418px
#
#                                                   play time_remaining quarter  \
# 0    1st quarter, 11:48.0 remaining<br>Lonzo Ball m...        11:48.0       1
# 1    1st quarter, 11:47.0 remaining<br>Derrick Favo...        11:47.0       1
# 205  1st quarter, 11:29.0 remaining<br>OG Anunoby m...        11:29.0       1
# 2    1st quarter, 11:16.0 remaining<br>Jrue Holiday...        11:16.0       1
# 206  1st quarter, 11:11.0 remaining<br>Kyle Lowry m...        11:11.0       1
#
#            shots_by outcome    attempt distance         team
# 0        Lonzo Ball  missed  2-pointer     11ft  New Orleans
# 1    Derrick Favors    made  2-pointer      1ft  New Orleans
# 205      OG Anunoby  missed  2-pointer      3ft      Toronto
# 2      Jrue Holiday  missed  2-pointer      8ft  New Orleans
# 206      Kyle Lowry  missed  3-pointer     25ft      Toronto

# %%
def get_winner_score(winner, team, play):
    desc = play.split('<br>')[2].split(' ')
    if desc[0] == "LA" or desc[0] == "New" or desc[0] == 'San' or desc[0] == 'Golden':
        if desc[2] == "trails" or desc[2] == "leads":
            #team score is in desc[2].split('-')[0]
            if winner == team:
                return desc[3].split('-')[0]
            else:
                return desc[3].split('-')[1]
        elif desc[3] == "trails" or desc[3] == "leads":
            #team score is in desc[3].split('-')[0]
            if winner == team:
                return desc[4].split('-')[0]
            else:
                return desc[4].split('-')[1]
        elif desc[2] == "tied":
            #"tied"
            return desc[3].split('-')[0]
        else:
            #now tied
            return desc[4].split('-')[0]
    else:
        if desc[1] == "trails" or desc[1] == "leads":
            #team score is in desc[2].split('-')[0]
            if winner == team:
                return desc[2].split('-')[0]
            else:
                return desc[2].split('-')[1]
        elif desc[2] == "trails" or desc[2] == "leads":
            #accounting for phrase "now leads" or "now trails"
            #team score is in desc[3].split('-')[0]
            if winner == team:
                return desc[3].split('-')[0]
            else:
                return desc[3].split('-')[1]
        elif desc[1] == "tied":
            #"tied"
            return desc[2].split('-')[0]
        else:
            #now tied
            return desc[3].split('-')[0]

# %%
def get_loser_score(loser, team, play):
    desc = play.split('<br>')[2].split(' ')
    if desc[0] == "LA" or desc[0] == "New" or desc[0] == 'San' or desc[0] == 'Golden':
        if desc[2] == "trails" or desc[2] == "leads":
            #team score is in desc[2].split('-')[2]
            if loser == team:
                return desc[3].split('-')[0]
            else:
                return desc[3].split('-')[1]
        elif desc[3] == "trails" or desc[3] == "leads":
            #team score is in desc[3].split('-')[2]
            if loser == team:
                return desc[4].split('-')[0]
            else:
                return desc[4].split('-')[1]
        elif desc[2] == "tied":
            #"tied"
            return desc[3].split('-')[0]
        else:
            #now tied
            return desc[4].split('-')[0]
    else:
        if desc[1] == "trails" or desc[1] == "leads":
            #team score is in desc[2].split('-')[2]
            if loser == team:
                return desc[2].split('-')[0]
            else:
                return desc[2].split('-')[1]
        elif desc[2] == "trails" or desc[2] == "leads":
            #team score is in desc[3].split('-')[2]
            if loser == team:
                return desc[3].split('-')[0]
            else:
                return desc[3].split('-')[1]
        elif desc[1] == "tied":
            #"tied"
            return desc[2].split('-')[0]
        else:
            #now tied
            return desc[3].split('-')[0]

# %%
final_df['winner_score'] = final_df.apply(lambda x: get_winner_score(x.winner, x.team, x.play), axis=1)

# %%
final_df[['play','winner_score']].head()
# Out:
#                                                   play winner_score
# 0    1st quarter, 11:48.0 remaining<br>Lonzo Ball m...            0
# 1    1st quarter, 11:47.0 remaining<br>Derrick Favo...            0
# 205  1st quarter, 11:29.0 remaining<br>OG Anunoby m...            0
# 2    1st quarter, 11:16.0 remaining<br>Jrue Holiday...            0
# 206  1st quarter, 11:11.0 remaining<br>Kyle Lowry m...            0

# %%
final_df['loser_score'] = final_df.apply(lambda x: get_loser_score(x.loser, x.team, x.play), axis=1)

# %%
final_df.head(50)
# Out:
#            game_id  year month day   winner        loser      x      y  \
# 0     201910220TOR  2019    10  22  Toronto  New Orleans  147px  242px
# 1     201910220TOR  2019    10  22  Toronto  New Orleans   27px  240px
# 205   201910220TOR  2019    10  22  Toronto  New Orleans   60px  256px
# 2     201910220TOR  2019    10  22  Toronto  New Orleans   32px  320px
# 206   201910220TOR  2019    10  22  Toronto  New Orleans  208px  418px
# 3     201910220TOR  2019    10  22  Toronto  New Orleans  152px  258px
# 4     201910220TOR  2019    10  22  Toronto  New Orleans  133px  366px
# 207   201910220TOR  2019    10  22  Toronto  New Orleans  279px  246px
# 5     201910220TOR  2019    10  22  Toronto  New Orleans  164px   31px
# 6     201910220TOR  2019    10  22  Toronto  New Orleans  291px  244px
# 7     201910220TOR  2019    10  22  Toronto  New Orleans   21px   16px
# 208   201910220TOR  2019    10  22  Toronto  New Orleans   16px  471px
# 8     201910220TOR  2019    10  22  Toronto  New Orleans  160px  304px
# 9     201910220TOR  2019    10  22  Toronto  New Orleans  155px  466px
# 10    201910220TOR  2019    10  22  Toronto  New Orleans  143px   90px
# 209   201910220TOR  2019    10  22  Toronto  New Orleans   38px  260px
# 286   201910220TOR  2019    10  22  Toronto  New Orleans  283px  249px
# 11    201910220TOR  2019    10  22  Toronto  New Orleans   50px  258px
# 287   201910220TOR  2019    10  22  Toronto  New Orleans  220px   82px
# 12    201910220TOR  2019    10  22  Toronto  New Orleans  254px  362px
# 288   201910220TOR  2019    10  22  Toronto  New Orleans   17px   10px
# 13    201910220TOR  2019    10  22  Toronto  New Orleans  158px   26px
# 289   201910220TOR  2019    10  22  Toronto  New Orleans   60px  217px
# 14    201910220TOR  2019    10  22  Toronto  New Orleans   54px  263px
# 290   201910220TOR  2019    10  22  Toronto  New Orleans   31px  253px
# 291   201910220TOR  2019    10  22  Toronto  New Orleans   39px  258px
# 292   201910220TOR  2019    10  22  Toronto  New Orleans   27px  240px
# 15    201910220TOR  2019    10  22  Toronto  New Orleans  168px  306px
# 293   201910220TOR  2019    10  22  Toronto  New Orleans   42px  478px
# 294   201910220TOR  2019    10  22  Toronto  New Orleans   36px  254px
# 16    201910220TOR  2019    10  22  Toronto  New Orleans  160px   33px
# 1551  201910220TOR  2019    10  22  Toronto  New Orleans   50px  259px
# 196   201910220TOR  2019    10  22  Toronto  New Orleans  231px  389px
# 1552  201910220TOR  2019    10  22  Toronto  New Orleans  141px   21px
# 17    201910220TOR  2019    10  22  Toronto  New Orleans  275px  159px
# 197   201910220TOR  2019    10  22  Toronto  New Orleans  172px  183px
# 18    201910220TOR  2019    10  22  Toronto  New Orleans  113px  243px
# 1553  201910220TOR  2019    10  22  Toronto  New Orleans   19px   15px
# 19    201910220TOR  2019    10  22  Toronto  New Orleans  269px  328px
# 198   201910220TOR  2019    10  22  Toronto  New Orleans   58px   31px
# 20    201910220TOR  2019    10  22  Toronto  New Orleans  163px  378px
# 21    201910220TOR  2019    10  22  Toronto  New Orleans  108px  250px
# 1554  201910220TOR  2019    10  22  Toronto  New Orleans  232px   95px
# 295   201910220TOR  2019    10  22  Toronto  New Orleans   36px  226px
# 22    201910220TOR  2019    10  22  Toronto  New Orleans  273px  333px
# 1555  201910220TOR  2019    10  22  Toronto  New Orleans   53px  266px
# 23    201910220TOR  2019    10  22  Toronto  New Orleans  105px  242px
# 199   201910220TOR  2019    10  22  Toronto  New Orleans   33px  222px
# 296   201910220TOR  2019    10  22  Toronto  New Orleans   32px  248px
# 24    201910220TOR  2019    10  22  Toronto  New Orleans   50px  252px
#
#                                                    play time_remaining  \
# 0     1st quarter, 11:48.0 remaining<br>Lonzo Ball m...        11:48.0
# 1     1st quarter, 11:47.0 remaining<br>Derrick Favo...        11:47.0
# 205   1st quarter, 11:29.0 remaining<br>OG Anunoby m...        11:29.0
# 2     1st quarter, 11:16.0 remaining<br>Jrue Holiday...        11:16.0
# 206   1st quarter, 11:11.0 remaining<br>Kyle Lowry m...        11:11.0
# 3     1st quarter, 11:00.0 remaining<br>Derrick Favo...        11:00.0
# 4     1st quarter, 10:37.0 remaining<br>Brandon Ingr...        10:37.0
# 207   1st quarter, 10:17.0 remaining<br>OG Anunoby m...        10:17.0
# 5     1st quarter, 10:11.0 remaining<br>Lonzo Ball m...        10:11.0
# 6     1st quarter, 9:55.0 remaining<br>Jrue Holiday ...         9:55.0
# 7     1st quarter, 9:39.0 remaining<br>Brandon Ingra...         9:39.0
# 208   1st quarter, 9:26.0 remaining<br>OG Anunoby mi...         9:26.0
# 8     1st quarter, 9:16.0 remaining<br>Brandon Ingra...         9:16.0
# 9     1st quarter, 9:02.0 remaining<br>J.J. Redick m...         9:02.0
# 10    1st quarter, 8:34.0 remaining<br>J.J. Redick m...         8:34.0
# 209   1st quarter, 8:23.0 remaining<br>Pascal Siakam...         8:23.0
# 286   1st quarter, 8:10.0 remaining<br>Pascal Siakam...         8:10.0
# 11    1st quarter, 7:57.0 remaining<br>Derrick Favor...         7:57.0
# 287   1st quarter, 7:32.0 remaining<br>Fred VanVleet...         7:32.0
# 12    1st quarter, 7:17.0 remaining<br>Lonzo Ball mi...         7:17.0
# 288   1st quarter, 6:59.0 remaining<br>Kyle Lowry ma...         6:59.0
# 13    1st quarter, 6:45.0 remaining<br>Brandon Ingra...         6:45.0
# 289   1st quarter, 6:30.0 remaining<br>Pascal Siakam...         6:30.0
# 14    1st quarter, 6:22.0 remaining<br>Derrick Favor...         6:22.0
# 290   1st quarter, 6:04.0 remaining<br>OG Anunoby ma...         6:04.0
# 291   1st quarter, 5:46.0 remaining<br>Pascal Siakam...         5:46.0
# 292   1st quarter, 5:45.0 remaining<br>Pascal Siakam...         5:45.0
# 15    1st quarter, 5:33.0 remaining<br>Derrick Favor...         5:33.0
# 293   1st quarter, 5:23.0 remaining<br>Serge Ibaka m...         5:23.0
# 294   1st quarter, 5:09.0 remaining<br>Fred VanVleet...         5:09.0
# 16    1st quarter, 4:54.0 remaining<br>Jrue Holiday ...         4:54.0
# 1551  1st overtime, 4:45.0 remaining<br>Norman Powel...         4:45.0
# 196   1st overtime, 4:31.0 remaining<br>J.J. Redick ...         4:31.0
# 1552  1st overtime, 4:20.0 remaining<br>Kyle Lowry m...         4:20.0
# 17    1st quarter, 4:10.0 remaining<br>Nickeil Alexa...         4:10.0
# 197   1st overtime, 4:07.0 remaining<br>Brandon Ingr...         4:07.0
# 18    1st quarter, 3:54.0 remaining<br>Nickeil Alexa...         3:54.0
# 1553  1st overtime, 3:53.0 remaining<br>OG Anunoby m...         3:53.0
# 19    1st quarter, 3:49.0 remaining<br>Kenrich Willi...         3:49.0
# 198   1st overtime, 3:41.0 remaining<br>Lonzo Ball m...         3:41.0
# 20    1st quarter, 3:32.0 remaining<br>E'Twaun Moore...         3:32.0
# 21    1st quarter, 3:29.0 remaining<br>E'Twaun Moore...         3:29.0
# 1554  1st overtime, 3:23.0 remaining<br>Marc Gasol m...         3:23.0
# 295   1st quarter, 3:22.0 remaining<br>Fred VanVleet...         3:22.0
# 22    1st quarter, 3:02.0 remaining<br>Nickeil Alexa...         3:02.0
# 1555  1st overtime, 2:37.0 remaining<br>Marc Gasol m...         2:37.0
# 23    1st quarter, 2:36.0 remaining<br>E'Twaun Moore...         2:36.0
# 199   1st overtime, 2:23.0 remaining<br>Jrue Holiday...         2:23.0
# 296   1st quarter, 2:22.0 remaining<br>Pascal Siakam...         2:22.0
# 24    1st quarter, 2:15.0 remaining<br>Jahlil Okafor...         2:15.0
#
#      quarter                  shots_by outcome    attempt distance  \
# 0          1                Lonzo Ball  missed  2-pointer     11ft
# 1          1            Derrick Favors    made  2-pointer      1ft
# 205        1                OG Anunoby  missed  2-pointer      3ft
# 2          1              Jrue Holiday  missed  2-pointer      8ft
# 206        1                Kyle Lowry  missed  3-pointer     25ft
# 3          1            Derrick Favors  missed  2-pointer     12ft
# 4          1            Brandon Ingram    made  2-pointer     16ft
# 207        1                OG Anunoby    made  3-pointer     25ft
# 5          1                Lonzo Ball    made  3-pointer     25ft
# 6          1              Jrue Holiday  missed  3-pointer     26ft
# 7          1            Brandon Ingram    made  3-pointer     22ft
# 208        1                OG Anunoby  missed  3-pointer     23ft
# 8          1            Brandon Ingram  missed  2-pointer     14ft
# 9          1               J.J. Redick    made  3-pointer     26ft
# 10         1               J.J. Redick    made  2-pointer     19ft
# 209        1             Pascal Siakam    made  2-pointer      2ft
# 286        1             Pascal Siakam  missed  3-pointer     25ft
# 11         1            Derrick Favors    made  2-pointer      2ft
# 287        1             Fred VanVleet    made  3-pointer     24ft
# 12         1                Lonzo Ball  missed  3-pointer     25ft
# 288        1                Kyle Lowry    made  3-pointer     23ft
# 13         1            Brandon Ingram  missed  3-pointer     25ft
# 289        1             Pascal Siakam  missed  2-pointer      4ft
# 14         1            Derrick Favors    made  2-pointer      3ft
# 290        1                OG Anunoby    made  2-pointer      1ft
# 291        1             Pascal Siakam  missed  2-pointer      2ft
# 292        1             Pascal Siakam    made  2-pointer      1ft
# 15         1            Derrick Favors  missed  2-pointer     15ft
# 293        1               Serge Ibaka  missed  3-pointer     24ft
# 294        1             Fred VanVleet    made  2-pointer      1ft
# 16         1              Jrue Holiday  missed  3-pointer     24ft
# 1551       1             Norman Powell    made  2-pointer      3ft
# 196        1               J.J. Redick    made  3-pointer     25ft
# 1552       1                Kyle Lowry  missed  3-pointer     24ft
# 17         1  Nickeil Alexander-Walker  missed  3-pointer     26ft
# 197        1            Brandon Ingram  missed  2-pointer     15ft
# 18         1  Nickeil Alexander-Walker  missed  2-pointer      8ft
# 1553       1                OG Anunoby  missed  3-pointer     23ft
# 19         1          Kenrich Williams  missed  3-pointer     25ft
# 198        1                Lonzo Ball  missed  2-pointer     21ft
# 20         1             E'Twaun Moore  missed  2-pointer     19ft
# 21         1             E'Twaun Moore  missed  2-pointer      8ft
# 1554       1                Marc Gasol  missed  3-pointer     25ft
# 295        1             Fred VanVleet    made  2-pointer      1ft
# 22         1  Nickeil Alexander-Walker    made  3-pointer     26ft
# 1555       1                Marc Gasol    made  2-pointer      3ft
# 23         1             E'Twaun Moore    made  2-pointer      7ft
# 199        1              Jrue Holiday    made  2-pointer      2ft
# 296        1             Pascal Siakam  missed  2-pointer      1ft
# 24         1             Jahlil Okafor    made  2-pointer      2ft
#
#              team winner_score loser_score
# 0     New Orleans            0           0
# 1     New Orleans            0           2
# 205       Toronto            0           2
# 2     New Orleans            0           2
# 206       Toronto            0           2
# 3     New Orleans            0           2
# 4     New Orleans            1           4
# 207       Toronto            4           4
# 5     New Orleans            4           7
# 6     New Orleans            4           7
# 7     New Orleans            4          10
# 208       Toronto            4          10
# 8     New Orleans            4          10
# 9     New Orleans            4          13
# 10    New Orleans            4          15
# 209       Toronto            6          15
# 286       Toronto            6          15
# 11    New Orleans            6          17
# 287       Toronto            9          17
# 12    New Orleans            9          17
# 288       Toronto           12          17
# 13    New Orleans           12          17
# 289       Toronto           12          17
# 14    New Orleans           12          19
# 290       Toronto           14          19
# 291       Toronto           14          19
# 292       Toronto           16          19
# 15    New Orleans           16          19
# 293       Toronto           16          19
# 294       Toronto           18          19
# 16    New Orleans           18          19
# 1551      Toronto          119         117
# 196   New Orleans          119         120
# 1552      Toronto          119         120
# 17    New Orleans           20          19
# 197   New Orleans          119         120
# 18    New Orleans           20          19
# 1553      Toronto          119         120
# 19    New Orleans           20          19
# 198   New Orleans          119         120
# 20    New Orleans           22          19
# 21    New Orleans           22          19
# 1554      Toronto          119         120
# 295       Toronto           24          19
# 22    New Orleans           25          22
# 1555      Toronto          121         120
# 23    New Orleans           25          24
# 199   New Orleans          122         122
# 296       Toronto           25          24
# 24    New Orleans           25          26

# %%
final_df.to_csv(file_name+'-final.csv')
