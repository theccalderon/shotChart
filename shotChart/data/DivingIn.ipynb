# %%
import pandas as pd

# %%
# !ls
# Out:
# DivingIn-spark.ipynb shots-2021.csv       shots-2022.tgz
# DivingIn.ipynb       shots-2021.tgz       shots-2023-wip.csv
# compress-finals.sh   shots-2022-wip.csv
# shots-2021-wip.csv   shots-2022.csv

# %%
file_name = "shots-2023"

# %%
shots = pd.read_csv(file_name+"-wip.csv")

# %%
shots.head()
# Out:
#         game_id  year  month  day   winner         loser      x      y  \
# 0  202310240GSW  2023     10   24  Phoenix  Golden State   67px  246px
# 1  202310240GSW  2023     10   24  Phoenix  Golden State   49px  200px
# 2  202310240GSW  2023     10   24  Phoenix  Golden State  116px  227px
# 3  202310240GSW  2023     10   24  Phoenix  Golden State   87px  182px
# 4  202310240GSW  2023     10   24  Phoenix  Golden State  228px  423px
#
#                                                 play
# 0  1st quarter, 11:28.0 remaining<br>Jusuf Nurkić...
# 1  1st quarter, 10:41.0 remaining<br>Devin Booker...
# 2  1st quarter, 10:09.0 remaining<br>Kevin Durant...
# 3  1st quarter, 10:02.0 remaining<br>Kevin Durant...
# 4  1st quarter, 9:25.0 remaining<br>Grayson Allen...

# %%
game_ids = shots.drop_duplicates(subset='game_id')['game_id'].tolist()

# %%
len(game_ids)
# Out:
# 1130

# %%
import datetime

# %%
list_of_columns = shots.columns.values.tolist() + ["time_remaining","quarter"]

# %%
print(list_of_columns)
# Out:
# ['game_id', 'year', 'month', 'day', 'winner', 'loser', 'x', 'y', 'play', 'time_remaining', 'quarter']

# %%
shots.loc[shots['game_id']=='202310240GSW'].head()
# Out:
#         game_id  year  month  day   winner         loser      x      y  \
# 0  202310240GSW  2023     10   24  Phoenix  Golden State   67px  246px
# 1  202310240GSW  2023     10   24  Phoenix  Golden State   49px  200px
# 2  202310240GSW  2023     10   24  Phoenix  Golden State  116px  227px
# 3  202310240GSW  2023     10   24  Phoenix  Golden State   87px  182px
# 4  202310240GSW  2023     10   24  Phoenix  Golden State  228px  423px
#
#                                                 play
# 0  1st quarter, 11:28.0 remaining<br>Jusuf Nurkić...
# 1  1st quarter, 10:41.0 remaining<br>Devin Booker...
# 2  1st quarter, 10:09.0 remaining<br>Kevin Durant...
# 3  1st quarter, 10:02.0 remaining<br>Kevin Durant...
# 4  1st quarter, 9:25.0 remaining<br>Grayson Allen...

# %%
final_df = pd.DataFrame(columns=list_of_columns)

# %%
final_df
# Out:
# Empty DataFrame
# Columns: [game_id, year, month, day, winner, loser, x, y, play, time_remaining, quarter]
# Index: []

# %%
for game in game_ids:
    temp_df = shots.loc[shots['game_id']==game]
    temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S')) 
    temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0]) 

    temp_df = temp_df.sort_values(by=['quarter','time_remaining'],ascending=[True,False])
#     print(temp_df.head())
    final_df = pd.concat([final_df, temp_df])
# Out:
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_df = pd.concat([final_df, temp_df])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['time_remaining'] = temp_df['play'].apply(lambda x: datetime.datetime.strptime(str(x).split(' ')[2], '%H:%M.%S'))
# /var/folders/c5/vksplvp52f5d7k58vwqjlx4m0000gn/T/ipykernel_65621/614039434.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['quarter'] = temp_df['play'].apply(lambda x: str(x).split(' ')[0][0])

# %%
final_df[final_df['game_id']== '202110190MIL']
# Out:
# Empty DataFrame
# Columns: [game_id, year, month, day, winner, loser, x, y, play, time_remaining, quarter]
# Index: []

# %%
final_df['time_remaining'] = final_df['play'].apply(lambda x: str(x).split(' ')[2])

# %%
final_df['shots_by'] = final_df['play'].apply(lambda x: str(x).split('<br>')[1].split(' ')[0]+" "+str(x).split('<br>')[1].split(' ')[1])

# %%
final_df.head()
# Out:
#          game_id  year month day   winner         loser      x      y  \
# 94  202310240GSW  2023    10  24  Phoenix  Golden State   90px  309px
# 0   202310240GSW  2023    10  24  Phoenix  Golden State   67px  246px
# 95  202310240GSW  2023    10  24  Phoenix  Golden State  237px   52px
# 96  202310240GSW  2023    10  24  Phoenix  Golden State   80px  210px
# 97  202310240GSW  2023    10  24  Phoenix  Golden State  123px  253px
#
#                                                  play time_remaining quarter  \
# 94  1st quarter, 11:50.0 remaining<br>Chris Paul m...        11:50.0       1
# 0   1st quarter, 11:28.0 remaining<br>Jusuf Nurkić...        11:28.0       1
# 95  1st quarter, 11:16.0 remaining<br>Stephen Curr...        11:16.0       1
# 96  1st quarter, 10:54.0 remaining<br>Kevon Looney...        10:54.0       1
# 97  1st quarter, 10:48.0 remaining<br>Andrew Wiggi...        10:48.0       1
#
#           shots_by
# 94      Chris Paul
# 0     Jusuf Nurkić
# 95   Stephen Curry
# 96    Kevon Looney
# 97  Andrew Wiggins

# %%
final_df['outcome'] = final_df['play'].apply(lambda x: str(x).split('<br>')[1].split(' ')[2])

# %%
final_df['attempt'] = final_df['play'].apply(lambda x: str(x).split('<br>')[1].split(' ')[3])

# %%
final_df.head()
# Out:
#          game_id  year month day   winner         loser      x      y  \
# 94  202310240GSW  2023    10  24  Phoenix  Golden State   90px  309px
# 0   202310240GSW  2023    10  24  Phoenix  Golden State   67px  246px
# 95  202310240GSW  2023    10  24  Phoenix  Golden State  237px   52px
# 96  202310240GSW  2023    10  24  Phoenix  Golden State   80px  210px
# 97  202310240GSW  2023    10  24  Phoenix  Golden State  123px  253px
#
#                                                  play time_remaining quarter  \
# 94  1st quarter, 11:50.0 remaining<br>Chris Paul m...        11:50.0       1
# 0   1st quarter, 11:28.0 remaining<br>Jusuf Nurkić...        11:28.0       1
# 95  1st quarter, 11:16.0 remaining<br>Stephen Curr...        11:16.0       1
# 96  1st quarter, 10:54.0 remaining<br>Kevon Looney...        10:54.0       1
# 97  1st quarter, 10:48.0 remaining<br>Andrew Wiggi...        10:48.0       1
#
#           shots_by outcome    attempt
# 94      Chris Paul  missed  2-pointer
# 0     Jusuf Nurkić    made  2-pointer
# 95   Stephen Curry    made  3-pointer
# 96    Kevon Looney  missed  2-pointer
# 97  Andrew Wiggins    made  2-pointer

# %%
#"1st quarter, 11:28.0 remaining<br>Patrick Beverley made 2-pointer from 2 ft<br>LA Clippers now leads 2-0"
final_df['distance'] = final_df['play'].apply(lambda x: str(x).split('<br>')[1].split(' ')[-2]+str(x).split('<br>')[1].split(' ')[-1])

# %%
final_df.head()
# Out:
#          game_id  year month day   winner         loser      x      y  \
# 94  202310240GSW  2023    10  24  Phoenix  Golden State   90px  309px
# 0   202310240GSW  2023    10  24  Phoenix  Golden State   67px  246px
# 95  202310240GSW  2023    10  24  Phoenix  Golden State  237px   52px
# 96  202310240GSW  2023    10  24  Phoenix  Golden State   80px  210px
# 97  202310240GSW  2023    10  24  Phoenix  Golden State  123px  253px
#
#                                                  play time_remaining quarter  \
# 94  1st quarter, 11:50.0 remaining<br>Chris Paul m...        11:50.0       1
# 0   1st quarter, 11:28.0 remaining<br>Jusuf Nurkić...        11:28.0       1
# 95  1st quarter, 11:16.0 remaining<br>Stephen Curr...        11:16.0       1
# 96  1st quarter, 10:54.0 remaining<br>Kevon Looney...        10:54.0       1
# 97  1st quarter, 10:48.0 remaining<br>Andrew Wiggi...        10:48.0       1
#
#           shots_by outcome    attempt distance
# 94      Chris Paul  missed  2-pointer      9ft
# 0     Jusuf Nurkić    made  2-pointer      4ft
# 95   Stephen Curry    made  3-pointer     28ft
# 96    Kevon Looney  missed  2-pointer      6ft
# 97  Andrew Wiggins    made  2-pointer      9ft

# %%
def get_team(play):
    team = play.split('<br>')[2].split(' ')
    if team[0] == "LA" or team[0] == "New" or team[0] == 'San' or team[0] == 'Golden':
        return team[0]+" "+team[1]
    else:
        return team[0]

# %%
final_df['team'] = final_df['play'].apply(lambda x: get_team(x))

# %%
final_df.head()
# Out:
#          game_id  year month day   winner         loser      x      y  \
# 94  202310240GSW  2023    10  24  Phoenix  Golden State   90px  309px
# 0   202310240GSW  2023    10  24  Phoenix  Golden State   67px  246px
# 95  202310240GSW  2023    10  24  Phoenix  Golden State  237px   52px
# 96  202310240GSW  2023    10  24  Phoenix  Golden State   80px  210px
# 97  202310240GSW  2023    10  24  Phoenix  Golden State  123px  253px
#
#                                                  play time_remaining quarter  \
# 94  1st quarter, 11:50.0 remaining<br>Chris Paul m...        11:50.0       1
# 0   1st quarter, 11:28.0 remaining<br>Jusuf Nurkić...        11:28.0       1
# 95  1st quarter, 11:16.0 remaining<br>Stephen Curr...        11:16.0       1
# 96  1st quarter, 10:54.0 remaining<br>Kevon Looney...        10:54.0       1
# 97  1st quarter, 10:48.0 remaining<br>Andrew Wiggi...        10:48.0       1
#
#           shots_by outcome    attempt distance          team
# 94      Chris Paul  missed  2-pointer      9ft  Golden State
# 0     Jusuf Nurkić    made  2-pointer      4ft       Phoenix
# 95   Stephen Curry    made  3-pointer     28ft  Golden State
# 96    Kevon Looney  missed  2-pointer      6ft  Golden State
# 97  Andrew Wiggins    made  2-pointer      9ft  Golden State

# %%
def get_winner_score(winner, team, play):
    desc = play.split('<br>')[2].split(' ')
    if desc[0] == "LA" or desc[0] == "New" or desc[0] == 'San' or desc[0] == 'Golden':
        if desc[2] == "trails" or desc[2] == "leads":
            #team score is in desc[2].split('-')[0]
            if winner == team:
                return desc[3].split('-')[0]
            else:
                return desc[3].split('-')[1]
        elif desc[3] == "trails" or desc[3] == "leads":
            #team score is in desc[3].split('-')[0]
            if winner == team:
                return desc[4].split('-')[0]
            else:
                return desc[4].split('-')[1]
        elif desc[2] == "tied":
            #"tied"
            return desc[3].split('-')[0]
        else:
            #now tied
            return desc[4].split('-')[0]
    else:
        if desc[1] == "trails" or desc[1] == "leads":
            #team score is in desc[2].split('-')[0]
            if winner == team:
                return desc[2].split('-')[0]
            else:
                return desc[2].split('-')[1]
        elif desc[2] == "trails" or desc[2] == "leads":
            #accounting for phrase "now leads" or "now trails"
            #team score is in desc[3].split('-')[0]
            if winner == team:
                return desc[3].split('-')[0]
            else:
                return desc[3].split('-')[1]
        elif desc[1] == "tied":
            #"tied"
            return desc[2].split('-')[0]
        else:
            #now tied
            return desc[3].split('-')[0]

# %%
def get_loser_score(loser, team, play):
    desc = play.split('<br>')[2].split(' ')
    if desc[0] == "LA" or desc[0] == "New" or desc[0] == 'San' or desc[0] == 'Golden':
        if desc[2] == "trails" or desc[2] == "leads":
            #team score is in desc[2].split('-')[2]
            if loser == team:
                return desc[3].split('-')[0]
            else:
                return desc[3].split('-')[1]
        elif desc[3] == "trails" or desc[3] == "leads":
            #team score is in desc[3].split('-')[2]
            if loser == team:
                return desc[4].split('-')[0]
            else:
                return desc[4].split('-')[1]
        elif desc[2] == "tied":
            #"tied"
            return desc[3].split('-')[0]
        else:
            #now tied
            return desc[4].split('-')[0]
    else:
        if desc[1] == "trails" or desc[1] == "leads":
            #team score is in desc[2].split('-')[2]
            if loser == team:
                return desc[2].split('-')[0]
            else:
                return desc[2].split('-')[1]
        elif desc[2] == "trails" or desc[2] == "leads":
            #team score is in desc[3].split('-')[2]
            if loser == team:
                return desc[3].split('-')[0]
            else:
                return desc[3].split('-')[1]
        elif desc[1] == "tied":
            #"tied"
            return desc[2].split('-')[0]
        else:
            #now tied
            return desc[3].split('-')[0]

# %%
final_df['winner_score'] = final_df.apply(lambda x: get_winner_score(x.winner, x.team, x.play), axis=1)

# %%
final_df[['play','winner_score']].head()
# Out:
#                                                  play winner_score
# 94  1st quarter, 11:50.0 remaining<br>Chris Paul m...            0
# 0   1st quarter, 11:28.0 remaining<br>Jusuf Nurkić...            2
# 95  1st quarter, 11:16.0 remaining<br>Stephen Curr...            3
# 96  1st quarter, 10:54.0 remaining<br>Kevon Looney...            3
# 97  1st quarter, 10:48.0 remaining<br>Andrew Wiggi...            3

# %%
final_df['loser_score'] = final_df.apply(lambda x: get_loser_score(x.loser, x.team, x.play), axis=1)

# %%
final_df.head(50)
# Out:
#           game_id  year month day   winner         loser      x      y  \
# 94   202310240GSW  2023    10  24  Phoenix  Golden State   90px  309px
# 0    202310240GSW  2023    10  24  Phoenix  Golden State   67px  246px
# 95   202310240GSW  2023    10  24  Phoenix  Golden State  237px   52px
# 96   202310240GSW  2023    10  24  Phoenix  Golden State   80px  210px
# 97   202310240GSW  2023    10  24  Phoenix  Golden State  123px  253px
# 1    202310240GSW  2023    10  24  Phoenix  Golden State   49px  200px
# 98   202310240GSW  2023    10  24  Phoenix  Golden State  315px  210px
# 2    202310240GSW  2023    10  24  Phoenix  Golden State  116px  227px
# 3    202310240GSW  2023    10  24  Phoenix  Golden State   87px  182px
# 99   202310240GSW  2023    10  24  Phoenix  Golden State  294px  338px
# 4    202310240GSW  2023    10  24  Phoenix  Golden State  228px  423px
# 5    202310240GSW  2023    10  24  Phoenix  Golden State  215px   54px
# 100  202310240GSW  2023    10  24  Phoenix  Golden State  267px  353px
# 6    202310240GSW  2023    10  24  Phoenix  Golden State   31px  403px
# 101  202310240GSW  2023    10  24  Phoenix  Golden State   59px  266px
# 102  202310240GSW  2023    10  24  Phoenix  Golden State  138px   95px
# 7    202310240GSW  2023    10  24  Phoenix  Golden State   81px  157px
# 103  202310240GSW  2023    10  24  Phoenix  Golden State  126px  227px
# 8    202310240GSW  2023    10  24  Phoenix  Golden State   57px  205px
# 104  202310240GSW  2023    10  24  Phoenix  Golden State   77px  236px
# 9    202310240GSW  2023    10  24  Phoenix  Golden State   93px  304px
# 105  202310240GSW  2023    10  24  Phoenix  Golden State  213px   46px
# 106  202310240GSW  2023    10  24  Phoenix  Golden State   53px  265px
# 10   202310240GSW  2023    10  24  Phoenix  Golden State  200px   62px
# 107  202310240GSW  2023    10  24  Phoenix  Golden State  147px  367px
# 11   202310240GSW  2023    10  24  Phoenix  Golden State  279px  198px
# 108  202310240GSW  2023    10  24  Phoenix  Golden State   65px  232px
# 12   202310240GSW  2023    10  24  Phoenix  Golden State  206px  329px
# 109  202310240GSW  2023    10  24  Phoenix  Golden State   54px  244px
# 13   202310240GSW  2023    10  24  Phoenix  Golden State  260px  149px
# 110  202310240GSW  2023    10  24  Phoenix  Golden State  278px   95px
# 14   202310240GSW  2023    10  24  Phoenix  Golden State   23px  133px
# 111  202310240GSW  2023    10  24  Phoenix  Golden State   60px  278px
# 112  202310240GSW  2023    10  24  Phoenix  Golden State  111px  238px
# 15   202310240GSW  2023    10  24  Phoenix  Golden State   53px  209px
# 113  202310240GSW  2023    10  24  Phoenix  Golden State   60px  283px
# 114  202310240GSW  2023    10  24  Phoenix  Golden State  313px  197px
# 115  202310240GSW  2023    10  24  Phoenix  Golden State   53px  278px
# 16   202310240GSW  2023    10  24  Phoenix  Golden State  205px   61px
# 116  202310240GSW  2023    10  24  Phoenix  Golden State   31px  465px
# 117  202310240GSW  2023    10  24  Phoenix  Golden State   95px  211px
# 118  202310240GSW  2023    10  24  Phoenix  Golden State  242px   64px
# 119  202310240GSW  2023    10  24  Phoenix  Golden State   79px  253px
# 120  202310240GSW  2023    10  24  Phoenix  Golden State   84px    7px
# 17   202310240GSW  2023    10  24  Phoenix  Golden State   98px  258px
# 121  202310240GSW  2023    10  24  Phoenix  Golden State   80px  221px
# 122  202310240GSW  2023    10  24  Phoenix  Golden State   51px  268px
# 123  202310240GSW  2023    10  24  Phoenix  Golden State   28px  286px
# 124  202310240GSW  2023    10  24  Phoenix  Golden State  262px  405px
# 18   202310240GSW  2023    10  24  Phoenix  Golden State  137px  381px
#
#                                                   play time_remaining quarter  \
# 94   1st quarter, 11:50.0 remaining<br>Chris Paul m...        11:50.0       1
# 0    1st quarter, 11:28.0 remaining<br>Jusuf Nurkić...        11:28.0       1
# 95   1st quarter, 11:16.0 remaining<br>Stephen Curr...        11:16.0       1
# 96   1st quarter, 10:54.0 remaining<br>Kevon Looney...        10:54.0       1
# 97   1st quarter, 10:48.0 remaining<br>Andrew Wiggi...        10:48.0       1
# 1    1st quarter, 10:41.0 remaining<br>Devin Booker...        10:41.0       1
# 98   1st quarter, 10:29.0 remaining<br>Andrew Wiggi...        10:29.0       1
# 2    1st quarter, 10:09.0 remaining<br>Kevin Durant...        10:09.0       1
# 3    1st quarter, 10:02.0 remaining<br>Kevin Durant...        10:02.0       1
# 99   1st quarter, 9:46.0 remaining<br>Chris Paul mi...         9:46.0       1
# 4    1st quarter, 9:25.0 remaining<br>Grayson Allen...         9:25.0       1
# 5    1st quarter, 9:20.0 remaining<br>Devin Booker ...         9:20.0       1
# 100  1st quarter, 9:05.0 remaining<br>Stephen Curry...         9:05.0       1
# 6    1st quarter, 8:52.0 remaining<br>Devin Booker ...         8:52.0       1
# 101  1st quarter, 8:41.0 remaining<br>Kevon Looney ...         8:41.0       1
# 102  1st quarter, 7:59.0 remaining<br>Klay Thompson...         7:59.0       1
# 7    1st quarter, 7:46.0 remaining<br>Kevin Durant ...         7:46.0       1
# 103  1st quarter, 7:33.0 remaining<br>Andrew Wiggin...         7:33.0       1
# 8    1st quarter, 7:25.0 remaining<br>Devin Booker ...         7:25.0       1
# 104  1st quarter, 7:18.0 remaining<br>Andrew Wiggin...         7:18.0       1
# 9    1st quarter, 6:55.0 remaining<br>Kevin Durant ...         6:55.0       1
# 105  1st quarter, 6:38.0 remaining<br>Klay Thompson...         6:38.0       1
# 106  1st quarter, 6:15.0 remaining<br>Kevon Looney ...         6:15.0       1
# 10   1st quarter, 6:10.0 remaining<br>Kevin Durant ...         6:10.0       1
# 107  1st quarter, 5:58.0 remaining<br>Klay Thompson...         5:58.0       1
# 11   1st quarter, 5:40.0 remaining<br>Devin Booker ...         5:40.0       1
# 108  1st quarter, 5:14.0 remaining<br>Andrew Wiggin...         5:14.0       1
# 12   1st quarter, 5:02.0 remaining<br>Devin Booker ...         5:02.0       1
# 109  1st quarter, 4:39.0 remaining<br>Kevon Looney ...         4:39.0       1
# 13   1st quarter, 4:28.0 remaining<br>Devin Booker ...         4:28.0       1
# 110  1st quarter, 4:22.0 remaining<br>Stephen Curry...         4:22.0       1
# 14   1st quarter, 4:08.0 remaining<br>Kevin Durant ...         4:08.0       1
# 111  1st quarter, 3:58.0 remaining<br>Jonathan Kumi...         3:58.0       1
# 112  1st quarter, 3:30.0 remaining<br>Jonathan Kumi...         3:30.0       1
# 15   1st quarter, 3:22.0 remaining<br>Eric Gordon m...         3:22.0       1
# 113  1st quarter, 3:13.0 remaining<br>Stephen Curry...         3:13.0       1
# 114  1st quarter, 3:00.0 remaining<br>Dario Šarić m...         3:00.0       1
# 115  1st quarter, 2:42.0 remaining<br>Moses Moody m...         2:42.0       1
# 16   1st quarter, 2:30.0 remaining<br>Eric Gordon m...         2:30.0       1
# 116  1st quarter, 2:14.0 remaining<br>Gary Payton I...         2:14.0       1
# 117  1st quarter, 2:08.0 remaining<br>Dario Šarić m...         2:08.0       1
# 118  1st quarter, 2:01.0 remaining<br>Moses Moody m...         2:01.0       1
# 119  1st quarter, 1:22.0 remaining<br>Klay Thompson...         1:22.0       1
# 120  1st quarter, 1:16.0 remaining<br>Moses Moody m...         1:16.0       1
# 17   1st quarter, 1:07.0 remaining<br>Eric Gordon m...         1:07.0       1
# 121  1st quarter, 0:47.0 remaining<br>Dario Šarić m...         0:47.0       1
# 122  1st quarter, 0:43.0 remaining<br>Dario Šarić m...         0:43.0       1
# 123  1st quarter, 0:35.0 remaining<br>Moses Moody m...         0:35.0       1
# 124  1st quarter, 0:04.0 remaining<br>Klay Thompson...         0:04.0       1
# 18   2nd quarter, 11:50.0 remaining<br>Jordan Goodw...        11:50.0       2
#
#              shots_by outcome    attempt distance          team winner_score  \
# 94         Chris Paul  missed  2-pointer      9ft  Golden State            0
# 0        Jusuf Nurkić    made  2-pointer      4ft       Phoenix            2
# 95      Stephen Curry    made  3-pointer     28ft  Golden State            3
# 96       Kevon Looney  missed  2-pointer      6ft  Golden State            3
# 97     Andrew Wiggins    made  2-pointer      9ft  Golden State            3
# 1        Devin Booker    made  2-pointer      4ft       Phoenix            5
# 98     Andrew Wiggins  missed  3-pointer     29ft  Golden State            5
# 2        Kevin Durant  missed  2-pointer      9ft       Phoenix            5
# 3        Kevin Durant    made  2-pointer      8ft       Phoenix            7
# 99         Chris Paul  missed  3-pointer     28ft  Golden State            7
# 4       Grayson Allen  missed  3-pointer     27ft       Phoenix            7
# 5        Devin Booker    made  3-pointer     26ft       Phoenix           10
# 100     Stephen Curry  missed  3-pointer     26ft  Golden State           10
# 6        Devin Booker    made  2-pointer     16ft       Phoenix           12
# 101      Kevon Looney    made  2-pointer      4ft  Golden State           13
# 102     Klay Thompson    made  2-pointer     18ft  Golden State           15
# 7        Kevin Durant    made  2-pointer     10ft       Phoenix           17
# 103    Andrew Wiggins    made  2-pointer     10ft  Golden State           17
# 8        Devin Booker  missed  2-pointer      4ft       Phoenix           17
# 104    Andrew Wiggins  missed  2-pointer      5ft  Golden State           17
# 9        Kevin Durant  missed  2-pointer      9ft       Phoenix           17
# 105     Klay Thompson  missed  3-pointer     27ft  Golden State           17
# 106      Kevon Looney  missed  2-pointer      3ft  Golden State           19
# 10       Kevin Durant  missed  3-pointer     25ft       Phoenix           19
# 107     Klay Thompson  missed  2-pointer     17ft  Golden State           19
# 11       Devin Booker    made  3-pointer     25ft       Phoenix           22
# 108    Andrew Wiggins  missed  2-pointer      4ft  Golden State           22
# 12       Devin Booker    made  2-pointer     20ft       Phoenix           24
# 109      Kevon Looney    made  2-pointer      2ft  Golden State           24
# 13       Devin Booker  missed  3-pointer     25ft       Phoenix           24
# 110     Stephen Curry    made  3-pointer     29ft  Golden State           24
# 14       Kevin Durant  missed  2-pointer     11ft       Phoenix           24
# 111  Jonathan Kuminga    made  2-pointer      5ft  Golden State           24
# 112  Jonathan Kuminga  missed  2-pointer      8ft  Golden State           25
# 15        Eric Gordon  missed  2-pointer      4ft       Phoenix           25
# 113     Stephen Curry    made  2-pointer      5ft  Golden State           25
# 114       Dario Šarić  missed  3-pointer     29ft  Golden State           25
# 115       Moses Moody    made  2-pointer      4ft  Golden State           25
# 16        Eric Gordon  missed  3-pointer     25ft       Phoenix           25
# 116       Gary Payton      II     missed     23ft  Golden State           25
# 117       Dario Šarić  missed  2-pointer      7ft  Golden State           25
# 118       Moses Moody  missed  3-pointer     28ft  Golden State           25
# 119     Klay Thompson  missed  2-pointer      5ft  Golden State           25
# 120       Moses Moody    made  3-pointer     24ft  Golden State           25
# 17        Eric Gordon    made  2-pointer      7ft       Phoenix           27
# 121       Dario Šarić  missed  2-pointer      5ft  Golden State           27
# 122       Dario Šarić  missed  2-pointer      3ft  Golden State           27
# 123       Moses Moody    made  2-pointer      5ft  Golden State           27
# 124     Klay Thompson  missed  3-pointer     28ft  Golden State           28
# 18     Jordan Goodwin  missed  2-pointer     18ft       Phoenix           28
#
#     loser_score
# 94            0
# 0             0
# 95            3
# 96            3
# 97            5
# 1             5
# 98            5
# 2             5
# 3             5
# 99            5
# 4             5
# 5             5
# 100           5
# 6             5
# 101           7
# 102           9
# 7             9
# 103          11
# 8            12
# 104          12
# 9            12
# 105          12
# 106          12
# 10           12
# 107          12
# 11           12
# 108          12
# 12           12
# 109          14
# 13           14
# 110          17
# 14           17
# 111          19
# 112          19
# 15           19
# 113          21
# 114          21
# 115          23
# 16           23
# 116          23
# 117          23
# 118          23
# 119          23
# 120          26
# 17           26
# 121          26
# 122          26
# 123          28
# 124          28
# 18           28

# %%
final_df.to_csv(file_name+'.csv')
